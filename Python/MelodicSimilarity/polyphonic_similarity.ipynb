# %% [markdown]
# ## Polyphonic Similarity

# %%
import music21
music21.environment.set('musicxmlPath', '/Applications/MuseScore.app')

from music21 import *
import matplotlib.pylab as plt
# %matplotlib inline

from IPython.display import Image

# %%
BCI = music21.corpus.getBachChorales()

# %%
bach_1 = converter.parse(BCI[3])

# %%
bach_2 = converter.parse(BCI[2])

# %%
Image(filename=bach_1.write('lily.png'))

# %%
Image(filename=bach_2.write('lily.png'))
